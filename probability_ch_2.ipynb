# %%
Chapter-2 for probability

# %% [markdown]
# ## Fundamentals of Combinatorics, Permutations and How to Use Them, Simple Operations with Factorials, Solving Variations with Repetition, Symmetry of Combinations.

# %%
4 persons and four chairs === permutations
4 persons out of 6 teams for four chairs == variations n==6 and p=4 (positions available)
which 4 out of 6 into the teams combinations so order is not relevant

# %%
permutation,
n! == is number of permutation to arrange N items or people or element

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n! is explained here
3! == 3 x2 x1 = 6
-ive dont have factorial and 0!==1
n! = (n-1)! x n  and (n+1)! = n!(n+1)

(n+k)! == n!x(n+1)x(n+2) xxxx (n+k)
(n-k)! == n!/[(n-k+1)(n-k+2)xxxxxx(n-k+k)]
if n>k then n!/k! == (k+1)x(k+2)x(k+3) xxxxx n

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##n is the number of elements or perople we have and p is positions or chairs(2) we need to fill.

# %%
# Variations  with repititions lock key password like a b c == 3x3==9==3^2

#Variations  with-out repititions running game of 5 people who runs first 
like a b c, d, e == 1, 2, 3, 4 (out of last two people) == 6 variation for last two positions(last two empty and first two filled)
4x6 == 24 ways to arrange three remaining starting position(means only first filled)
if we dont know which to start then 24x5 == 120 ways to choose
if we go from 1 to 4 our multiple options are decreasing == we cant use the same person twice
5x4x3x2x1=120 how we can arrange our people without repitition   ?????????????

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Solving combinations
how to pick elements of a set == pick 3 people to represent company out of 10 people company
3 are same choosing what ever first second or third and we dont care order
6 permutations here are different variation and not a different combination

combination take into account double counting p_3=6(3x2x1) permutations = 
120 combinations C_3{^10} and variations is 720==V_3{^10}
c=v/p, see below formula with n==10 and p=3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Symmetry Explained

# %%
6 fruit and room for 4 only
combinations = C_6{^4}=6!/2!4!==15
bigger bosket 5 pieces.... 6 by 6 is 1 pick all of them
so choosing 7 out of 10 and leaving 3 behind is same choosing 3 and leaving behind 7

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#               Combinations with separate sample spaces

# %%
3 sandwhich types, 2 fries finger and ring, and 2 drink water and cola
3x2x2 == 12 
several version of online adds and choose best
multiply each event and get the option

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#                      Winning the Lottery

# %%
P(A).P(B) == product of probability of 2 event together
likely hood of two independent event occur together
choosing 5 number and then chhosing poerball number (p=5 and 69=n total)
1/26 ,x combination without repition as order does not matter
26 time less likely

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Combinations with Repetition

# %%
#    Combinations with repetition

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#               Application of combination with repetition

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#                   Pizza example

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#                          Methodology

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#                  Pizzas and sequence

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#             Always ending in zero

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#             Positions

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#              Final Step

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
End of the topic
